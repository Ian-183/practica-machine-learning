# %% [markdown]
# <p align="center">
#   <img src="img/logoitqv1.png" width="270" style="margin-right: 20px;">
# </p>
# <div style="clear:both;"></div>
#
# ##  3_1_3_var_cualitativas
# #  July 13, 2026
#
# <p align="center">
#   <img src="img/python_logo.png" width="220" style="margin-left: 20px;">
# </p>
# <div style="clear:both;"></div>
#
# *Elvis David Pachacama*
#
# *Ian Mijail Morales Patiño*
#
# 0.1 01PAO26-26 - Variables cualitativa
#
# <br>
# <a href="https://github.com/Ian-183/practica-machine-learning">https://github.com/Ian-183/practica-machine-learningb</a>

# %%
 # Creación aleatoria de datos
import numpy as np
import random
random.seed(42)

# %%
nivel_estudios = []
nivel_estudios.extend(['Secundaria']*110)
nivel_estudios.extend(['Bachillerato']*172)
nivel_estudios.extend(['Grado']*145)
nivel_estudios.extend(['Master']*52)
nivel_estudios.extend(['Doctorado']*21)
nivel_estudios = np.random.permutation(nivel_estudios)

# %%
print(nivel_estudios)
# Out:
# ['Secundaria' 'Grado' 'Grado' 'Secundaria' 'Bachillerato' 'Grado' 'Master'
#  'Bachillerato' 'Doctorado' 'Bachillerato' 'Master' 'Bachillerato'
#  'Doctorado' 'Bachillerato' 'Bachillerato' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Grado' 'Master' 'Bachillerato' 'Bachillerato'
#  'Secundaria' 'Bachillerato' 'Grado' 'Grado' 'Master' 'Grado' 'Grado'
#  'Bachillerato' 'Master' 'Bachillerato' 'Grado' 'Secundaria' 'Master'
#  'Master' 'Grado' 'Grado' 'Grado' 'Grado' 'Bachillerato' 'Master'
#  'Bachillerato' 'Grado' 'Secundaria' 'Secundaria' 'Grado' 'Grado' 'Grado'
#  'Bachillerato' 'Bachillerato' 'Master' 'Bachillerato' 'Bachillerato'
#  'Grado' 'Bachillerato' 'Master' 'Grado' 'Bachillerato' 'Secundaria'
#  'Master' 'Secundaria' 'Bachillerato' 'Secundaria' 'Master' 'Secundaria'
#  'Doctorado' 'Secundaria' 'Master' 'Secundaria' 'Grado' 'Bachillerato'
#  'Grado' 'Grado' 'Master' 'Bachillerato' 'Bachillerato' 'Secundaria'
#  'Doctorado' 'Master' 'Bachillerato' 'Secundaria' 'Secundaria' 'Grado'
#  'Bachillerato' 'Grado' 'Grado' 'Bachillerato' 'Secundaria' 'Bachillerato'
#  'Master' 'Bachillerato' 'Bachillerato' 'Grado' 'Bachillerato' 'Grado'
#  'Bachillerato' 'Secundaria' 'Grado' 'Grado' 'Bachillerato' 'Bachillerato'
#  'Secundaria' 'Doctorado' 'Grado' 'Grado' 'Grado' 'Secundaria' 'Grado'
#  'Master' 'Secundaria' 'Grado' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Secundaria' 'Bachillerato' 'Bachillerato' 'Doctorado'
#  'Master' 'Bachillerato' 'Master' 'Doctorado' 'Grado' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Bachillerato' 'Secundaria' 'Grado'
#  'Bachillerato' 'Doctorado' 'Grado' 'Doctorado' 'Master' 'Grado'
#  'Secundaria' 'Bachillerato' 'Bachillerato' 'Secundaria' 'Master' 'Grado'
#  'Grado' 'Bachillerato' 'Bachillerato' 'Master' 'Secundaria' 'Grado'
#  'Grado' 'Master' 'Grado' 'Secundaria' 'Bachillerato' 'Doctorado'
#  'Bachillerato' 'Grado' 'Grado' 'Grado' 'Grado' 'Bachillerato' 'Grado'
#  'Bachillerato' 'Secundaria' 'Grado' 'Bachillerato' 'Grado' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Secundaria' 'Grado' 'Grado' 'Secundaria'
#  'Secundaria' 'Bachillerato' 'Secundaria' 'Secundaria' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Bachillerato' 'Grado' 'Master' 'Grado'
#  'Secundaria' 'Bachillerato' 'Secundaria' 'Bachillerato' 'Grado'
#  'Bachillerato' 'Grado' 'Grado' 'Doctorado' 'Grado' 'Secundaria'
#  'Secundaria' 'Bachillerato' 'Bachillerato' 'Master' 'Doctorado'
#  'Bachillerato' 'Grado' 'Bachillerato' 'Grado' 'Grado' 'Master'
#  'Bachillerato' 'Bachillerato' 'Secundaria' 'Doctorado' 'Grado' 'Grado'
#  'Secundaria' 'Bachillerato' 'Master' 'Secundaria' 'Bachillerato' 'Grado'
#  'Bachillerato' 'Master' 'Secundaria' 'Master' 'Secundaria' 'Grado'
#  'Master' 'Bachillerato' 'Grado' 'Grado' 'Grado' 'Secundaria'
#  'Bachillerato' 'Secundaria' 'Secundaria' 'Master' 'Secundaria'
#  'Bachillerato' 'Grado' 'Bachillerato' 'Grado' 'Master' 'Doctorado'
#  'Secundaria' 'Grado' 'Secundaria' 'Master' 'Bachillerato' 'Grado'
#  'Secundaria' 'Bachillerato' 'Bachillerato' 'Master' 'Bachillerato'
#  'Grado' 'Secundaria' 'Grado' 'Grado' 'Bachillerato' 'Bachillerato'
#  'Grado' 'Grado' 'Secundaria' 'Secundaria' 'Bachillerato' 'Bachillerato'
#  'Secundaria' 'Bachillerato' 'Bachillerato' 'Bachillerato' 'Bachillerato'
#  'Grado' 'Doctorado' 'Master' 'Master' 'Bachillerato' 'Bachillerato'
#  'Master' 'Grado' 'Doctorado' 'Master' 'Master' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Secundaria' 'Secundaria' 'Master' 'Bachillerato'
#  'Secundaria' 'Grado' 'Grado' 'Grado' 'Bachillerato' 'Bachillerato'
#  'Grado' 'Grado' 'Secundaria' 'Secundaria' 'Secundaria' 'Grado' 'Grado'
#  'Secundaria' 'Bachillerato' 'Secundaria' 'Grado' 'Grado' 'Grado'
#  'Doctorado' 'Bachillerato' 'Bachillerato' 'Secundaria' 'Grado' 'Grado'
#  'Master' 'Secundaria' 'Bachillerato' 'Secundaria' 'Bachillerato' 'Master'
#  'Secundaria' 'Bachillerato' 'Secundaria' 'Secundaria' 'Grado'
#  'Bachillerato' 'Bachillerato' 'Bachillerato' 'Secundaria' 'Secundaria'
#  'Grado' 'Secundaria' 'Master' 'Grado' 'Secundaria' 'Grado' 'Bachillerato'
#  'Master' 'Grado' 'Secundaria' 'Bachillerato' 'Secundaria' 'Bachillerato'
#  'Master' 'Bachillerato' 'Bachillerato' 'Grado' 'Grado' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Bachillerato' 'Bachillerato' 'Secundaria'
#  'Master' 'Secundaria' 'Bachillerato' 'Secundaria' 'Grado' 'Secundaria'
#  'Bachillerato' 'Secundaria' 'Secundaria' 'Master' 'Secundaria'
#  'Bachillerato' 'Secundaria' 'Bachillerato' 'Bachillerato' 'Grado'
#  'Secundaria' 'Secundaria' 'Secundaria' 'Grado' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Grado' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Secundaria' 'Secundaria' 'Secundaria' 'Grado' 'Master'
#  'Grado' 'Grado' 'Bachillerato' 'Grado' 'Grado' 'Grado' 'Grado' 'Grado'
#  'Bachillerato' 'Grado' 'Secundaria' 'Bachillerato' 'Master'
#  'Bachillerato' 'Secundaria' 'Doctorado' 'Secundaria' 'Grado' 'Secundaria'
#  'Bachillerato' 'Bachillerato' 'Secundaria' 'Grado' 'Doctorado' 'Grado'
#  'Bachillerato' 'Grado' 'Secundaria' 'Grado' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Grado' 'Secundaria' 'Bachillerato' 'Bachillerato'
#  'Grado' 'Secundaria' 'Bachillerato' 'Bachillerato' 'Bachillerato' 'Grado'
#  'Bachillerato' 'Bachillerato' 'Grado' 'Grado' 'Master' 'Grado'
#  'Bachillerato' 'Secundaria' 'Grado' 'Bachillerato' 'Bachillerato' 'Grado'
#  'Bachillerato' 'Secundaria' 'Grado' 'Grado' 'Secundaria' 'Bachillerato'
#  'Secundaria' 'Grado' 'Grado' 'Master' 'Bachillerato' 'Bachillerato'
#  'Secundaria' 'Doctorado' 'Grado' 'Secundaria' 'Bachillerato'
#  'Bachillerato' 'Secundaria' 'Grado' 'Grado' 'Grado' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Bachillerato' 'Secundaria' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Secundaria' 'Bachillerato' 'Secundaria'
#  'Bachillerato' 'Secundaria' 'Bachillerato' 'Bachillerato' 'Grado' 'Grado'
#  'Bachillerato' 'Secundaria' 'Doctorado' 'Bachillerato' 'Grado'
#  'Bachillerato' 'Bachillerato' 'Secundaria' 'Bachillerato' 'Secundaria'
#  'Master' 'Grado' 'Bachillerato' 'Bachillerato' 'Bachillerato' 'Grado'
#  'Secundaria' 'Secundaria' 'Grado' 'Grado' 'Bachillerato']

# %%
# DIAGRAMA DE BARRAS
import matplotlib.pyplot as plt
import numpy as np
estudios, frecuencia = np.unique(nivel_estudios, return_counts=True)
print(estudios, frecuencia)
# Out:
# ['Bachillerato' 'Doctorado' 'Grado' 'Master' 'Secundaria'] [172  21 145  52 110]

# %%
plt.ylabel('Frecuencia absoluta')
plt.xlabel('Nivel de estudios')
plt.title('Diagrama de barras')
plt.bar(estudios, frecuencia) # https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.bar.html
plt.show()

# %%
# DIAGRAMA DE SECTORES
colores = {'red', 'blue', 'orange', 'green', 'cyan'}
plt.pie(frecuencia, labels=estudios, colors=colores, autopct='%1.2f%%')
plt.title('Diagrama de sectores')
plt.show()

# %%
# Tarea implementar con pandas esta información
import random
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

random.seed(42)

nivel_estudios = []
nivel_estudios.extend(['Secundaria'] * 110)
nivel_estudios.extend(['Bachillerato'] * 172)
nivel_estudios.extend(['Grado'] * 145)
nivel_estudios.extend(['Master'] * 52)
nivel_estudios.extend(['Doctorado'] * 21)

nivel_estudios = np.random.permutation(nivel_estudios)

df = pd.DataFrame(nivel_estudios, columns=['Nivel_Estudios'])

# %%
frecuencia = df['Nivel_Estudios'].value_counts()
print(frecuencia)
# Out:
# Nivel_Estudios
# Bachillerato    172
# Grado           145
# Secundaria      110
# Master           52
# Doctorado        21
# Name: count, dtype: int64

# %%
frecuencia.plot(kind='bar')
plt.ylabel('Frecuencia absoluta')
plt.xlabel('Nivel de estudios')
plt.title('Diagrama de barras')
plt.xticks(rotation=0)
plt.show()

# %%
colores = ['orange', 'blue', 'green', 'cyan', 'red']
frecuencia.plot(kind='pie', autopct='%1.2f%%', colors=colores, ylabel='')
plt.title('Diagrama de sectores')
plt.show()
